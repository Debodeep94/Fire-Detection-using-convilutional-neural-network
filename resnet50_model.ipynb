# %%
import os
from torchvision import datasets
import torchvision
import torch
from torchvision.transforms import transforms
import torchvision.models as models
import numpy as np
from PIL import ImageFile
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
ImageFile.LOAD_TRUNCATED_IMAGES = True
plt.ion()

# %%
batch_size = 64
num_workers = 0

transform = transforms.Compose([
    transforms.Resize(size=(256,256)),
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
train_set = '/content/drive/MyDrive/fire_dataset/train'
valid_set = '/content/drive/MyDrive/fire_dataset/test'


train_data = datasets.ImageFolder(train_set, transform=transform)
valid_data = datasets.ImageFolder(valid_set, transform=transform)

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, num_workers=num_workers, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size, num_workers=num_workers, shuffle=True)

loaders = {
    'train': train_loader,
    'valid': valid_loader
}

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
class_names = ['Fire', 'No_fire']
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(loaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
model = models.resnet50(pretrained=True)

use_cuda = torch.cuda.is_available()

if use_cuda:
    model = model.cuda()
    
model
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# HBox(children=(FloatProgress(value=0.0, max=102502400.0), HTML(value='')))
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
for param in model.parameters():
    param.requires_grad = False

model.fc = torch.nn.Sequential(torch.nn.Linear(2048,128),
                                      torch.nn.ReLU(),
                                       torch.nn.Linear(128,3),
                                       torch.nn.Softmax()
                                      )

for param in model.fc.parameters():
    param.requires_grad = True
    
if use_cuda:
    model_transfer = model.cuda()
    
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=3, bias=True)
#     (3): Softmax(dim=None)
#   )
# )

# %%
model

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_transfer.fc.parameters(), lr=0.0005)

# %%
n_epochs = 100

train_accuracy_list = []
train_loss_list = []
valid_accuracy_list = []
valid_loss_list = []

def train(n_epochs, loader, model, optimizer, criterion, use_cuda, save_path):
    
    valid_loss_min = np.Inf
       
    for epoch in range(1, (n_epochs+1)):
        
        train_loss = 0.0
        valid_loss = 0.0
        train_acc = 0.0
        valid_acc = 0.0
        
        model.train()
        
        for batch_idx, (data, target) in enumerate(loaders['train']):
            
            if use_cuda:
                data, target = data.cuda(), target.cuda()

            optimizer.zero_grad()
            output = model(data)
            _, preds = torch.max(output, 1)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            
            train_acc = train_acc + torch.sum(preds == target.data)
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
            model.eval()
        for batch_idx, (data, target) in enumerate(loaders['valid']):

            if use_cuda:
                data, target = data.cuda(), target.cuda()
            output = model(data)
            _, preds = torch.max(output, 1)
            loss = criterion(output, target)
            
            valid_acc = valid_acc + torch.sum(preds == target.data)
            valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))
            
        train_loss = train_loss/len(loaders['train'].dataset)
        valid_loss = valid_loss/len(loaders['valid'].dataset)
        train_acc = train_acc/len(loaders['train'].dataset)
        valid_acc = valid_acc/len(loaders['valid'].dataset)
        
        train_accuracy_list.append(train_acc)
        train_loss_list.append(train_loss)
        valid_accuracy_list.append(valid_acc)
        valid_loss_list.append(valid_loss)
        
        print('Epoch: {} \tTraining Acc: {:6f} \tTraining Loss: {:6f} \tValidation Acc: {:6f} \tValidation Loss: {:.6f}'.format(
            epoch,
            train_acc,
            train_loss,
            valid_acc,
            valid_loss
            ))

        if valid_loss <= valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            torch.save(model.state_dict(), save_path)
            valid_loss_min = valid_loss  
            
    return model

# %%
model = train(n_epochs, loaders, model, optimizer, criterion, use_cuda, '/content/model_final.pth')
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Epoch: 1 	Training Acc: 0.710024 	Training Loss: 0.000963 	Validation Acc: 0.987395 	Validation Loss: 0.002769
# Validation loss decreased (inf --> 0.002769).  Saving model ...
# Epoch: 2 	Training Acc: 0.958234 	Training Loss: 0.000768 	Validation Acc: 0.974790 	Validation Loss: 0.002497
# Validation loss decreased (0.002769 --> 0.002497).  Saving model ...
# Epoch: 3 	Training Acc: 0.972554 	Training Loss: 0.000719 	Validation Acc: 0.991597 	Validation Loss: 0.002408
# Validation loss decreased (0.002497 --> 0.002408).  Saving model ...
# Epoch: 4 	Training Acc: 0.972554 	Training Loss: 0.000712 	Validation Acc: 0.991597 	Validation Loss: 0.002404
# Validation loss decreased (0.002408 --> 0.002404).  Saving model ...
# Epoch: 5 	Training Acc: 0.967780 	Training Loss: 0.000706 	Validation Acc: 0.974790 	Validation Loss: 0.002446
# Epoch: 6 	Training Acc: 0.973747 	Training Loss: 0.000698 	Validation Acc: 0.995798 	Validation Loss: 0.002378
# Validation loss decreased (0.002404 --> 0.002378).  Saving model ...
# Epoch: 7 	Training Acc: 0.978520 	Training Loss: 0.000701 	Validation Acc: 0.962185 	Validation Loss: 0.002482
# Epoch: 8 	Training Acc: 0.963007 	Training Loss: 0.000712 	Validation Acc: 1.000000 	Validation Loss: 0.002352
# Validation loss decreased (0.002378 --> 0.002352).  Saving model ...
# Epoch: 9 	Training Acc: 0.967780 	Training Loss: 0.000700 	Validation Acc: 0.991597 	Validation Loss: 0.002366
# Epoch: 10 	Training Acc: 0.976134 	Training Loss: 0.000696 	Validation Acc: 0.995798 	Validation Loss: 0.002356
# Epoch: 11 	Training Acc: 0.970167 	Training Loss: 0.000696 	Validation Acc: 0.978992 	Validation Loss: 0.002422
# Epoch: 12 	Training Acc: 0.963007 	Training Loss: 0.000707 	Validation Acc: 0.983193 	Validation Loss: 0.002431
# Epoch: 13 	Training Acc: 0.971360 	Training Loss: 0.000697 	Validation Acc: 0.995798 	Validation Loss: 0.002340
# Validation loss decreased (0.002352 --> 0.002340).  Saving model ...
# Epoch: 14 	Training Acc: 0.974940 	Training Loss: 0.000693 	Validation Acc: 0.991597 	Validation Loss: 0.002399
# Epoch: 15 	Training Acc: 0.979714 	Training Loss: 0.000688 	Validation Acc: 0.991597 	Validation Loss: 0.002356
# Epoch: 16 	Training Acc: 0.977327 	Training Loss: 0.000689 	Validation Acc: 0.995798 	Validation Loss: 0.002351
# Epoch: 17 	Training Acc: 0.968974 	Training Loss: 0.000694 	Validation Acc: 0.966387 	Validation Loss: 0.002471
# Epoch: 18 	Training Acc: 0.974940 	Training Loss: 0.000704 	Validation Acc: 0.983193 	Validation Loss: 0.002414
# Epoch: 19 	Training Acc: 0.974940 	Training Loss: 0.000692 	Validation Acc: 0.983193 	Validation Loss: 0.002401
# Epoch: 20 	Training Acc: 0.974940 	Training Loss: 0.000689 	Validation Acc: 0.995798 	Validation Loss: 0.002341
# Epoch: 21 	Training Acc: 0.974940 	Training Loss: 0.000697 	Validation Acc: 0.962185 	Validation Loss: 0.002506
# Epoch: 22 	Training Acc: 0.963007 	Training Loss: 0.000719 	Validation Acc: 0.995798 	Validation Loss: 0.002332
# Validation loss decreased (0.002340 --> 0.002332).  Saving model ...
# Epoch: 23 	Training Acc: 0.971360 	Training Loss: 0.000699 	Validation Acc: 1.000000 	Validation Loss: 0.002339
# Epoch: 24 	Training Acc: 0.971360 	Training Loss: 0.000696 	Validation Acc: 0.991597 	Validation Loss: 0.002377
# Epoch: 25 	Training Acc: 0.982100 	Training Loss: 0.000682 	Validation Acc: 0.987395 	Validation Loss: 0.002440
# Epoch: 26 	Training Acc: 0.968974 	Training Loss: 0.000695 	Validation Acc: 0.995798 	Validation Loss: 0.002351
# Epoch: 27 	Training Acc: 0.974940 	Training Loss: 0.000700 	Validation Acc: 0.991597 	Validation Loss: 0.002357
# Epoch: 28 	Training Acc: 0.972554 	Training Loss: 0.000692 	Validation Acc: 0.995798 	Validation Loss: 0.002347
# Epoch: 29 	Training Acc: 0.976134 	Training Loss: 0.000690 	Validation Acc: 0.983193 	Validation Loss: 0.002401
# Epoch: 30 	Training Acc: 0.972554 	Training Loss: 0.000692 	Validation Acc: 1.000000 	Validation Loss: 0.002321
# Validation loss decreased (0.002332 --> 0.002321).  Saving model ...
# Epoch: 31 	Training Acc: 0.976134 	Training Loss: 0.000687 	Validation Acc: 0.970588 	Validation Loss: 0.002445
# Epoch: 32 	Training Acc: 0.976134 	Training Loss: 0.000689 	Validation Acc: 0.970588 	Validation Loss: 0.002440
# Epoch: 33 	Training Acc: 0.974940 	Training Loss: 0.000687 	Validation Acc: 0.995798 	Validation Loss: 0.002350
# Epoch: 34 	Training Acc: 0.982100 	Training Loss: 0.000683 	Validation Acc: 0.991597 	Validation Loss: 0.002364
# Epoch: 35 	Training Acc: 0.977327 	Training Loss: 0.000685 	Validation Acc: 0.970588 	Validation Loss: 0.002423
# Epoch: 36 	Training Acc: 0.983294 	Training Loss: 0.000681 	Validation Acc: 1.000000 	Validation Loss: 0.002334
# Epoch: 37 	Training Acc: 0.979714 	Training Loss: 0.000683 	Validation Acc: 0.983193 	Validation Loss: 0.002398
# Epoch: 38 	Training Acc: 0.967780 	Training Loss: 0.000692 	Validation Acc: 0.991597 	Validation Loss: 0.002358
# Epoch: 39 	Training Acc: 0.967780 	Training Loss: 0.000693 	Validation Acc: 0.995798 	Validation Loss: 0.002362
# Epoch: 40 	Training Acc: 0.984487 	Training Loss: 0.000683 	Validation Acc: 0.957983 	Validation Loss: 0.002460
# Epoch: 41 	Training Acc: 0.974940 	Training Loss: 0.000702 	Validation Acc: 0.991597 	Validation Loss: 0.002358
# Epoch: 42 	Training Acc: 0.977327 	Training Loss: 0.000684 	Validation Acc: 1.000000 	Validation Loss: 0.002325
# Epoch: 43 	Training Acc: 0.976134 	Training Loss: 0.000685 	Validation Acc: 0.970588 	Validation Loss: 0.002445
# Epoch: 44 	Training Acc: 0.973747 	Training Loss: 0.000688 	Validation Acc: 0.991597 	Validation Loss: 0.002348
# Epoch: 45 	Training Acc: 0.980907 	Training Loss: 0.000681 	Validation Acc: 0.995798 	Validation Loss: 0.002355
# Epoch: 46 	Training Acc: 0.979714 	Training Loss: 0.000684 	Validation Acc: 0.953782 	Validation Loss: 0.002496
# Epoch: 47 	Training Acc: 0.972554 	Training Loss: 0.000689 	Validation Acc: 1.000000 	Validation Loss: 0.002331
# Epoch: 48 	Training Acc: 0.972554 	Training Loss: 0.000685 	Validation Acc: 0.991597 	Validation Loss: 0.002386
# Epoch: 49 	Training Acc: 0.978520 	Training Loss: 0.000698 	Validation Acc: 1.000000 	Validation Loss: 0.002319
# Validation loss decreased (0.002321 --> 0.002319).  Saving model ...
# Epoch: 50 	Training Acc: 0.982100 	Training Loss: 0.000681 	Validation Acc: 0.983193 	Validation Loss: 0.002362
# Epoch: 51 	Training Acc: 0.978520 	Training Loss: 0.000693 	Validation Acc: 0.991597 	Validation Loss: 0.002366
# Epoch: 52 	Training Acc: 0.980907 	Training Loss: 0.000682 	Validation Acc: 1.000000 	Validation Loss: 0.002322
# Epoch: 53 	Training Acc: 0.973747 	Training Loss: 0.000687 	Validation Acc: 0.983193 	Validation Loss: 0.002403
# Epoch: 54 	Training Acc: 0.980907 	Training Loss: 0.000682 	Validation Acc: 0.987395 	Validation Loss: 0.002390
# Epoch: 55 	Training Acc: 0.976134 	Training Loss: 0.000685 	Validation Acc: 0.995798 	Validation Loss: 0.002352
# Epoch: 56 	Training Acc: 0.988067 	Training Loss: 0.000676 	Validation Acc: 0.978992 	Validation Loss: 0.002417
# Epoch: 57 	Training Acc: 0.984487 	Training Loss: 0.000676 	Validation Acc: 0.991597 	Validation Loss: 0.002375
# Epoch: 58 	Training Acc: 0.980907 	Training Loss: 0.000680 	Validation Acc: 0.995798 	Validation Loss: 0.002336
# Epoch: 59 	Training Acc: 0.972554 	Training Loss: 0.000687 	Validation Acc: 0.987395 	Validation Loss: 0.002386
# Epoch: 60 	Training Acc: 0.980907 	Training Loss: 0.000680 	Validation Acc: 0.987395 	Validation Loss: 0.002379
# Epoch: 61 	Training Acc: 0.983294 	Training Loss: 0.000678 	Validation Acc: 0.991597 	Validation Loss: 0.002375
# Epoch: 62 	Training Acc: 0.980907 	Training Loss: 0.000681 	Validation Acc: 0.987395 	Validation Loss: 0.002377
# Epoch: 63 	Training Acc: 0.983294 	Training Loss: 0.000690 	Validation Acc: 0.983193 	Validation Loss: 0.002432
# Epoch: 64 	Training Acc: 0.965394 	Training Loss: 0.000707 	Validation Acc: 0.991597 	Validation Loss: 0.002353
# Epoch: 65 	Training Acc: 0.984487 	Training Loss: 0.000679 	Validation Acc: 0.991597 	Validation Loss: 0.002347
# Epoch: 66 	Training Acc: 0.986874 	Training Loss: 0.000676 	Validation Acc: 0.991597 	Validation Loss: 0.002368
# Epoch: 67 	Training Acc: 0.983294 	Training Loss: 0.000677 	Validation Acc: 0.991597 	Validation Loss: 0.002365
# Epoch: 68 	Training Acc: 0.978520 	Training Loss: 0.000693 	Validation Acc: 0.962185 	Validation Loss: 0.002476
# Epoch: 69 	Training Acc: 0.976134 	Training Loss: 0.000687 	Validation Acc: 1.000000 	Validation Loss: 0.002318
# Validation loss decreased (0.002319 --> 0.002318).  Saving model ...
# Epoch: 70 	Training Acc: 0.977327 	Training Loss: 0.000684 	Validation Acc: 0.962185 	Validation Loss: 0.002472
# Epoch: 71 	Training Acc: 0.976134 	Training Loss: 0.000684 	Validation Acc: 0.983193 	Validation Loss: 0.002383
# Epoch: 72 	Training Acc: 0.982100 	Training Loss: 0.000677 	Validation Acc: 0.995798 	Validation Loss: 0.002336
# Epoch: 73 	Training Acc: 0.983294 	Training Loss: 0.000678 	Validation Acc: 0.974790 	Validation Loss: 0.002429
# Epoch: 74 	Training Acc: 0.984487 	Training Loss: 0.000678 	Validation Acc: 0.995798 	Validation Loss: 0.002345
# Epoch: 75 	Training Acc: 0.976134 	Training Loss: 0.000684 	Validation Acc: 0.962185 	Validation Loss: 0.002449
# Epoch: 76 	Training Acc: 0.976134 	Training Loss: 0.000686 	Validation Acc: 0.995798 	Validation Loss: 0.002340
# Epoch: 77 	Training Acc: 0.979714 	Training Loss: 0.000680 	Validation Acc: 0.974790 	Validation Loss: 0.002459
# Epoch: 78 	Training Acc: 0.982100 	Training Loss: 0.000677 	Validation Acc: 1.000000 	Validation Loss: 0.002321
# Epoch: 79 	Training Acc: 0.986874 	Training Loss: 0.000676 	Validation Acc: 0.987395 	Validation Loss: 0.002357
# Epoch: 80 	Training Acc: 0.986874 	Training Loss: 0.000676 	Validation Acc: 0.978992 	Validation Loss: 0.002383
# Epoch: 81 	Training Acc: 0.984487 	Training Loss: 0.000677 	Validation Acc: 0.995798 	Validation Loss: 0.002354
# Epoch: 82 	Training Acc: 0.983294 	Training Loss: 0.000680 	Validation Acc: 0.987395 	Validation Loss: 0.002375
# Epoch: 83 	Training Acc: 0.982100 	Training Loss: 0.000678 	Validation Acc: 0.983193 	Validation Loss: 0.002375
# Epoch: 84 	Training Acc: 0.982100 	Training Loss: 0.000679 	Validation Acc: 0.978992 	Validation Loss: 0.002398
# Epoch: 85 	Training Acc: 0.980907 	Training Loss: 0.000679 	Validation Acc: 0.978992 	Validation Loss: 0.002401
# Epoch: 86 	Training Acc: 0.973747 	Training Loss: 0.000687 	Validation Acc: 1.000000 	Validation Loss: 0.002321
# Epoch: 87 	Training Acc: 0.989260 	Training Loss: 0.000672 	Validation Acc: 0.970588 	Validation Loss: 0.002455
# Epoch: 88 	Training Acc: 0.983294 	Training Loss: 0.000677 	Validation Acc: 0.962185 	Validation Loss: 0.002486
# Epoch: 89 	Training Acc: 0.986874 	Training Loss: 0.000673 	Validation Acc: 1.000000 	Validation Loss: 0.002361
# Epoch: 90 	Training Acc: 0.979714 	Training Loss: 0.000680 	Validation Acc: 0.995798 	Validation Loss: 0.002344
# Epoch: 91 	Training Acc: 0.986874 	Training Loss: 0.000672 	Validation Acc: 0.991597 	Validation Loss: 0.002357
# Epoch: 92 	Training Acc: 0.983294 	Training Loss: 0.000676 	Validation Acc: 0.987395 	Validation Loss: 0.002367
# Epoch: 93 	Training Acc: 0.982100 	Training Loss: 0.000685 	Validation Acc: 0.974790 	Validation Loss: 0.002414
# Epoch: 94 	Training Acc: 0.980907 	Training Loss: 0.000681 	Validation Acc: 0.995798 	Validation Loss: 0.002338
# Epoch: 95 	Training Acc: 0.978520 	Training Loss: 0.000681 	Validation Acc: 0.983193 	Validation Loss: 0.002404
# Epoch: 96 	Training Acc: 0.983294 	Training Loss: 0.000676 	Validation Acc: 0.991597 	Validation Loss: 0.002343
# Epoch: 97 	Training Acc: 0.985680 	Training Loss: 0.000682 	Validation Acc: 0.991597 	Validation Loss: 0.002359
# Epoch: 98 	Training Acc: 0.979714 	Training Loss: 0.000680 	Validation Acc: 0.953782 	Validation Loss: 0.002494
# Epoch: 99 	Training Acc: 0.979714 	Training Loss: 0.000681 	Validation Acc: 0.978992 	Validation Loss: 0.002398
# Epoch: 100 	Training Acc: 0.989260 	Training Loss: 0.000672 	Validation Acc: 0.983193 	Validation Loss: 0.002384

# %%
plt.style.use("ggplot")
plt.figure()
plt.plot(train_loss_list, label="train_loss")
plt.title("Train-Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend(loc="lower left")

# %%
plt.style.use("ggplot")
plt.figure()

plt.plot(train_accuracy_list, label="train_acc")
plt.plot(valid_accuracy_list, label="valid_acc")

plt.title("Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")

# %%
torch.save(model, '/content/model_fitted.pth')

# %%
from PIL import Image

class_names = class_names = ['Fire', 'No_fire']

def predict(image):
    prediction_transform = transforms.Compose([transforms.Resize(size=(224, 224)),
                                     transforms.ToTensor(), 
                                     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

    image = prediction_transform(image)[:3,:,:].unsqueeze(0)
    image = image.cuda()

    pred = model(image)
    idx = torch.argmax(pred)
    prob = pred[0][idx].item()*100
    
    return class_names[idx], prob

# %%
def app(path):
    img = Image.open(path)
    plt.imshow(img)
    plt.show()

    prediction, prob = predict(img)
    print(prediction, prob)
    

for img_file in os.listdir('/content/drive/MyDrive/fire_dataset/test'):
    img_path = os.path.join('/content/drive/MyDrive/fire_dataset/test', img_file)
    app(img_path)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-18-8c762af9abc6> in <module>()
#      10 for img_file in os.listdir('/content/drive/MyDrive/fire_dataset/test'):
#      11     img_path = os.path.join('/content/drive/MyDrive/fire_dataset/test', img_file)
# ---> 12     app(img_path)
#
# <ipython-input-18-8c762af9abc6> in app(path)
#       1 def app(path):
# ----> 2     img = Image.open(path)
#       3     plt.imshow(img)
#       4     plt.show()
#       5
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# IsADirectoryError: [Errno 21] Is a directory: '/content/drive/MyDrive/fire_dataset/test/fire'

# %%
print("[INFO] loading model...")
model = torch.load('/content/model_fitted.pth')
# Out:
# [INFO] loading model...

# %%
class_names = class_names = ['Fire', 'No_fire']

def predict(image):
    prediction_transform = transforms.Compose([transforms.Resize(size=(224, 224)),
                                     transforms.ToTensor(), 
                                     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

    image = prediction_transform(image)[:3,:,:].unsqueeze(0)
    image = image.cuda()

    pred = model(image)
    idx = torch.argmax(pred)
    prob = pred[0][idx].item()*100
    
    return class_names[idx], prob

# %%
img = Image.open('/content/drive/MyDrive/fire_dataset/test/fire/fire.101.jpg')
plt.imshow(img)
plt.show()

prediction, prob = predict(img)
print(prediction, prob)
# Out:
# Fire 99.92074370384216
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:117: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
